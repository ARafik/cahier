# %% [markdown]
# # Test conversion JupyterR to pdf

# %%
mat1<-matrix(1:15,nrow=3,ncol=5)

# %%
mat2<-t(mat1)

# %%
plot(rnorm(10),rnorm(10,10,5),pch=19)
# Out:
# plot without title

# %%
require(graphics); require(grDevices)
x  <- as.matrix(mtcars)
rc <- rainbow(nrow(x), start = 0, end = .3)
cc <- rainbow(ncol(x), start = 0, end = .3)
heatmap(x, Colv = NA, col = cm.colors(256), scale = "column",
        RowSideColors = rc, margins = c(5,10),
        xlab = "specification variables", ylab =  "Car Models",
        main = "heatmap(<Mtcars data>, ..., scale = \"column\")")
# Out:
# Plot with title “heatmap(<Mtcars data>, ..., scale = "column")”

# %%
require(vegan)
data(varespec)
vare.mds <- metaMDS(varespec, trace = FALSE)
data(varechem)
ef <- envfit(vare.mds, varechem, permu = 999)
ef
# Out:
# Loading required package: vegan
# Loading required package: permute
# Loading required package: lattice
# This is vegan 2.4-4
# Error in envfit(vare.mds, varechem, permu = 999): object 'vare.mds' not found
# Traceback:
#
# 1. envfit(vare.mds, varechem, permu = 999)
